# %%
# import libraries
from selenium import webdriver
from scrapy import Selector
import requests
import pandas as pd

# %%
# define parameters for url, get requests, and selector

# to remove column limit; otherwise some data could be lost
pd.set_option('max_colwidth',500)   

# indeed.com url for data scientist in scottsdale arizona, sorted by date
base_url = 'https://www.indeed.com/jobs?q=data+scientist&l=Scottsdale%2C+AZ&sort=date'

# start page #
start_from = '&start='

# set initial page to 1
page = 1

# will need to delete beleo if already used in main loop
url = base_url + start_from + str(page)

# Create the string html containing the HTML source
html = requests.get( url = url).content
  
# create selector object
sel = Selector( text=html )

# %%
# MAIN LOOP

# initialize lists for each field 
job_titles = []
job_links = []
job_postings = []
company_names = []
company_links = []
locations = []
summary = []
ratings = []

# initialize pandas dataframe
df = pd.DataFrame()

# loop through pages 1 - 20 (indeed refers to them in multiples of 10 )
for page in range(1, 5):
    # indeed refers to pages in multiples of 10
    page = (page - 1) * 10
    # combined url with parameters
    url = base_url + start_from + str(page)
    # printed the urls to confirm they were valid web address
    print(url)

    # created the html containing the HTML source
    html = requests.get( url = url).content
  
    # created selector object
    sel = Selector( text=html ) 
        
    # pull job titles and append to list   
    job_titles.append(sel.xpath('//div[@class="title"]/a/@title').extract())
  
    # pull job links and append to list
    job_links.append(sel.xpath('//div[@class="title"]/a/@href').extract())

    # pull job posting(date) and append to list
    job_postings.append(sel.xpath('//span[@class="date "]/text()').extract())

    # pull company_names and append to list   
    company_names.append(sel.xpath('//span[@class="company"]/a/text()').extract())

    # pull company_links and append to list  
    company_links.append(sel.xpath('//span[@class="company"]/a/@href').extract())        # print(company_links)
   
    # pull locations and append to list
    locations.append(sel.css('div.sjcl > span::text').extract())
    
    # pull sumamry and append
    summary.append(sel.xpath('//div[@class="summary"]//text()').extract())

    # pull ratings and append to list
    ratings.append(sel.xpath('//span[@class="ratingsContent"]/text()').extract())
# Out:
# https://www.indeed.com/jobs?q=data+scientist&l=Scottsdale%2C+AZ&sort=date&start=0
# https://www.indeed.com/jobs?q=data+scientist&l=Scottsdale%2C+AZ&sort=date&start=10
# https://www.indeed.com/jobs?q=data+scientist&l=Scottsdale%2C+AZ&sort=date&start=20
# https://www.indeed.com/jobs?q=data+scientist&l=Scottsdale%2C+AZ&sort=date&start=30

# %%
# initialize lists to hold header information and combined list data
data = []
header_list = []

# zip together separate lists for each field
data = zip(job_titles, job_links, job_postings, company_names, company_links, locations, summary, ratings)

# add header list to idenftiy fields
header_list = ['job_titles', 'job_links', 'job_postings', 'company_names', 'company_links', 'locations', 'summary', 'ratings']
         
# zip together header and data lists    
zip_list = zip(header_list, data)

# unpack headers and data from zipped list
headers, data = zip(*zip_list)

# unpack data fields from zipped list
job_titles, job_links, job_postings, company_names, company_links, locations, summary, ratings = zip(*data)

# %%
# create pandas dataframe structured as a dictionary 
df = pd.DataFrame({'company_name': company_names, 'job_title': job_titles, 
                'job_link': job_links, 'job_posted': job_postings,
                'company_link': company_links, 'job_location': locations,
                'job_summary' : summary, "ratings" : ratings,
                'overall_rating': None, 'wl_bal_rating': None, 
                'benefit_rating': None, 'jsecurity_rating': None, 
                'mgmt_rating': None, 'culture_rating': None,
                'reviews_count' : None
                })

# %%
print(df)
# Out:
#                                                                                                                                                                                                                               company_name  \
# 0               [\nUSAA, \nUSAA, \nWells Fargo Bank, \nUSAA, \nCircle K, \nCircle K, \nTransPerfect, \nDiscover Financial Services, \nNationwide Mutual Insurance Company, \nAmerican Express, \nLighthouse, \nShamrock Foods, \nDeloitte]
# 1  [\nUSAA, \nDeloitte, \nUSAA, \nLifesprk, \nHealth Services Advisory Group, Inc., \nWipro Limited, \nAmerican Express, \nFreeport McMoRan, \nUSAA, \nDiscount Tire Corporate Careers, \nNationwide Mutual Insurance Company, \nFreestar]
# 2                                                                                                          [\nUSAA, \nUSAA, \nLifesprk, \nAlbertsons Companies, \nUSAA, \nMcKesson, \nUSAA, \nBNP Paribas, \nAmerican Express, \nDeloitte]
# 3               [\nUSAA, \nUSAA, \nLifesprk, \nTivity Health, Inc., \nWells Fargo, \nInsight Enterprises, Inc., \nDeloitte, \nDeloitte, \nBrightside, \nViaSat, \nStatistics & ,  Corporation (SDC), \nMUFG, \nCable One Inc., \nDeloitte]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              job_title  \
# 0                                                                                [Data Scientist I, Data Scientist Senior, DATA ENGINEER - ANALYTIC CONSULTANT 4, Data Scientist Lead, Data Scientist, Data Scientist, Manager (Global Projects), Data Entry, Senior Data Science Analyst, Consultant, Data Science, Senior Data Analyst, Information Security Specialist - Data Science, Data Scientist, Senior Business Intelligence Data Analyst, Sports Statistician, Data Scientist – Solution Specialist - USDC]
# 1                                                                                                          [Data Scientist I, Data Scientist – Solution Specialist - USDC, Sports Statistician, Data Scientist Senior, Staff Data Scientist - Engineering, Sr. Data Scientist, 2020 Summer Paid Internship Program, AI/Machine Learning, Data Science-Lead, Senior Data Analyst, Ph.D. Level Mathematician (M/F), Data Scientist I, Data Scientist I, Data Scientist II, Specialist, Data Science, Sr. Data Scientist]
# 2                                    [Data Scientist Senior, Data Scientist I, Staff Data Scientist - Engineering, Lead Data Scientist, Data Science Engineer, Data & Analytics, Data Scientist Senior, Data Science Intern (Summer 2020), Data Scientist Lead, Intern - INFORMATION TECHNOLOGY - Data Science Intern, Language Researcher / Data Analyst, Process Analyst/Data Scientist Internship, Machine Learning Engineer, Data Scientist – Solution Specialist - USDC, Sports Statistician, Sr. Data Scientist]
# 3  [Sr. Data Scientist, Data Scientist I, Sports Statistician, Data Scientist Senior, Staff Data Scientist - Engineering, Senior Data Analyst, Business Analytics (Senior Outcomes Analyst), Quantitative Analytics Specialist 3 / NLP Model Development Team - AI MD CoE, Pricing & Master Data Analyst II, Sr. Data Scientist – Senior Solution Specialist - USDC, Analytics & Cognitive - Cloud Data Streaming, Senior Consultant – AWS/Azure/GCP, Data Scientist, Data Scientist, Strategic Consulting Statisti...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
# 0                         [Tempe, AZ, Tempe, AZ, Phoenix, AZ 85003, Phoenix, AZ, Scottsdale, AZ, Scottsdale, AZ 85250 , Phoenix, AZ, Phoenix, AZ 85009 , Phoenix, AZ 85018 ]
# 1  [Phoenix, AZ 85020 , Phoenix, AZ, Phoenix, AZ 85027 , Phoenix, AZ, Tempe, AZ 85282 , Phoenix, AZ 85004 , Phoenix, AZ 85085 , Scottsdale, AZ, Scottsdale, AZ, Phoenix, AZ]
# 2                 [Phoenix, AZ, Phoenix, AZ 85027 , Phoenix, AZ 85085 , Scottsdale, AZ 85262 , Phoenix, AZ 85085 , Tempe, AZ, Phoenix, AZ, Phoenix, AZ, Phoenix, AZ, \n, \n]
# 3            [Chandler, AZ 85286, Tempe, AZ, Tempe, AZ 85284, Gilbert, AZ 85297, Phoenix, AZ, Chandler, AZ, Tempe, AZ 85284, Tempe, AZ, Tempe, AZ 85281, Phoenix, AZ 85012 ]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            job_summary  \
# 0  [\n,  \n , Uses advanced techniques that integrate traditional and non-traditional datasets and method to enable analytical solutions; Applies predictive analytics,…, \n, \n,  \n , Uses advanced techniques that integrate traditional and non-traditional datasets to enable analytical solutions; Applies predictive analytics, machine learning,…, \n, \n,  \n , 6+ years of experience in one or a combination of the following: reporting, analytics, or modeling; or a Masters degree or higher in a qua...
# 1  [\n,  \n , Uses advanced techniques that integrate traditional and non-traditional datasets and method to enable analytical solutions; Applies predictive analytics,…, \n, \n,  \n , The Analytics & Cognitive team leverages the power of data, analytics, robotics, science and cognitive technologies to uncover hidden relationships from vast…, \n, \n,  \n , You will get a thorough training in using the company software which is used for entering the data in order to provide the best analyses of t...
# 2  [\n,  \n , Uses advanced techniques that integrate traditional and non-traditional datasets to enable analytical solutions; Applies predictive analytics, machine learning,…, \n, \n,  \n , Uses advanced techniques that integrate traditional and non-traditional datasets and method to enable analytical solutions; Applies predictive analytics,…, \n, \n,  \n , Building a collaborative and service-oriented data and analytics discipline that empowers subject matter experts with data and tools throu...
# 3  [\n,  \n , Lead the deployment of ensemble machine learning methods, deep learning, and advanced optimization techniques to drill into our toughest challenges., \n, \n,  \n , Uses advanced techniques that integrate traditional and non-traditional datasets and method to enable analytical solutions; Applies predictive analytics,…, \n, \n,  \n , You will get a thorough training in using the company software which is used for entering the data in order to provide the best analyses of the game as...
#
#                                                                                                                                                       ratings  \
# 0             [\n3.9, \n, \n3.9, \n, \n3.7, \n, \n3.9, \n, \n3.3, \n, \n3.3, \n, \n3.0, \n, \n3.9, \n, \n3.9, \n, \n4.1, \n, \n3.7, \n, \n3.2, \n, \n4.0, \n]
# 1                        [\n3.9, \n, \n4.0, \n, \n3.9, \n, \n3.5, \n, \n3.0, \n, \n3.8, \n, \n4.1, \n, \n4.1, \n, \n3.9, \n, \n4.0, \n, \n3.9, \n, \n4.3, \n]
# 2                                              [\n3.9, \n, \n3.9, \n, \n3.5, \n, \n3.7, \n, \n3.9, \n, \n3.6, \n, \n3.9, \n, \n3.9, \n, \n4.1, \n, \n4.0, \n]
# 3  [\n3.9, \n, \n3.9, \n, \n3.5, \n, \n3.0, \n, \n3.7, \n, \n3.6, \n, \n4.0, \n, \n4.0, \n, \n3.4, \n, \n3.8, \n, \n3.6, \n, \n3.5, \n, \n3.8, \n, \n4.0, \n]
#
#   overall_rating wl_bal_rating benefit_rating jsecurity_rating mgmt_rating  \
# 0           None          None           None             None        None
# 1           None          None           None             None        None
# 2           None          None           None             None        None
# 3           None          None           None             None        None
#
#   culture_rating reviews_count
# 0           None          None
# 1           None          None
# 2           None          None
# 3           None          None

# %%
# initialize list to hold links to company websites 
url_list = []

# add url prefix to link
pre_url = 'http://www.indeed.com/cmp/'
# add reviews to end of link

# iterate through all company review links for all companies in first list
for list in df['company_name']:
    # iterate through each line
    for line in list:
        # iterate through each line
        # confirm there is data in field
        if len(line) > 0: 
            
            # create full url by concatentaing strings (stripping whitespace from company name)
            full_url = pre_url + line.replace(' ', '-').strip()
                
            # strip whitespace from link
            full_url.strip()
    
            # print full_url to confirm valid website
            # print(full_url)
                
            # Create a second html for each company reveiw website
            html2 = requests.get( full_url ).content

            # Create the Selector object set from html
            sel2 = Selector( text=html2 )
                       
            # use selector list to pull all company ratings and review count              
            comp_rating_overall = sel2.css('.cmp-CompactHeaderCompanyRatings-value::text').extract()
            wl_rating = sel2.xpath('//*[@data-tn-element="review-filter-wlbalance"]/*[@class="cmp-TopicFilter-rating"]/text()').extract()
            benefits_rating = sel2.xpath('//*[@data-tn-element="review-filter-paybenefits"]/*[@class="cmp-TopicFilter-rating"]/text()').extract()
            sec_rating = sel2.xpath('//*[@data-tn-element="review-filter-jobsecadv"]/*[@class="cmp-TopicFilter-rating"]/text()').extract()
            mgmt_rating = sel2.xpath('//*[@data-tn-element="review-filter-mgmt"]/*[@class="cmp-TopicFilter-rating"]/text()').extract()
            culture_rating = sel2.xpath('//*[@data-tn-element="review-filter-culture"]/*[@class="cmp-TopicFilter-rating"]/text()').extract()
            reviews_count = sel2.css('.cmp-RatingsCountLink::text').extract()
            
        else:
            print('None')

# %%
# print head of dataframe
print(df.head)
# Out:
# <bound method NDFrame.head of                                                                                                                                                                                                                               company_name  \
# 0               [\nUSAA, \nUSAA, \nWells Fargo Bank, \nUSAA, \nCircle K, \nCircle K, \nTransPerfect, \nDiscover Financial Services, \nNationwide Mutual Insurance Company, \nAmerican Express, \nLighthouse, \nShamrock Foods, \nDeloitte]
# 1  [\nUSAA, \nDeloitte, \nUSAA, \nLifesprk, \nHealth Services Advisory Group, Inc., \nWipro Limited, \nAmerican Express, \nFreeport McMoRan, \nUSAA, \nDiscount Tire Corporate Careers, \nNationwide Mutual Insurance Company, \nFreestar]
# 2                                                                                                          [\nUSAA, \nUSAA, \nLifesprk, \nAlbertsons Companies, \nUSAA, \nMcKesson, \nUSAA, \nBNP Paribas, \nAmerican Express, \nDeloitte]
# 3               [\nUSAA, \nUSAA, \nLifesprk, \nTivity Health, Inc., \nWells Fargo, \nInsight Enterprises, Inc., \nDeloitte, \nDeloitte, \nBrightside, \nViaSat, \nStatistics & ,  Corporation (SDC), \nMUFG, \nCable One Inc., \nDeloitte]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                

#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            job_summary  \
# 0  [\n,  \n , Uses advanced techniques that integrate traditional and non-traditional datasets and method to enable analytical solutions; Applies predictive analytics,…, \n, \n,  \n , Uses advanced techniques that integrate traditional and non-traditional datasets to enable analytical solutions; Applies predictive analytics, machine learning,…, \n, \n,  \n , 6+ years of experience in one or a combination of the following: reporting, analytics, or modeling; or a Masters degree or higher in a qua...
# 1  [\n,  \n , Uses advanced techniques that integrate traditional and non-traditional datasets and method to enable analytical solutions; Applies predictive analytics,…, \n, \n,  \n , The Analytics & Cognitive team leverages the power of data, analytics, robotics, science and cognitive technologies to uncover hidden relationships from vast…, \n, \n,  \n , You will get a thorough training in using the company software which is used for entering the data in order to provide the best analyses of t...
# 2  [\n,  \n , Uses advanced techniques that integrate traditional and non-traditional datasets to enable analytical solutions; Applies predictive analytics, machine learning,…, \n, \n,  \n , Uses advanced techniques that integrate traditional and non-traditional datasets and method to enable analytical solutions; Applies predictive analytics,…, \n, \n,  \n , Building a collaborative and service-oriented data and analytics discipline that empowers subject matter experts with data and tools throu...
# 3  [\n,  \n , Lead the deployment of ensemble machine learning methods, deep learning, and advanced optimization techniques to drill into our toughest challenges., \n, \n,  \n , Uses advanced techniques that integrate traditional and non-traditional datasets and method to enable analytical solutions; Applies predictive analytics,…, \n, \n,  \n , You will get a thorough training in using the company software which is used for entering the data in order to provide the best analyses of the game as...
#
#                                                                                                                                                       ratings  \
# 0             [\n3.9, \n, \n3.9, \n, \n3.7, \n, \n3.9, \n, \n3.3, \n, \n3.3, \n, \n3.0, \n, \n3.9, \n, \n3.9, \n, \n4.1, \n, \n3.7, \n, \n3.2, \n, \n4.0, \n]
# 1                        [\n3.9, \n, \n4.0, \n, \n3.9, \n, \n3.5, \n, \n3.0, \n, \n3.8, \n, \n4.1, \n, \n4.1, \n, \n3.9, \n, \n4.0, \n, \n3.9, \n, \n4.3, \n]
# 2                                              [\n3.9, \n, \n3.9, \n, \n3.5, \n, \n3.7, \n, \n3.9, \n, \n3.6, \n, \n3.9, \n, \n3.9, \n, \n4.1, \n, \n4.0, \n]
# 3  [\n3.9, \n, \n3.9, \n, \n3.5, \n, \n3.0, \n, \n3.7, \n, \n3.6, \n, \n4.0, \n, \n4.0, \n, \n3.4, \n, \n3.8, \n, \n3.6, \n, \n3.5, \n, \n3.8, \n, \n4.0, \n]
#
#   overall_rating wl_bal_rating benefit_rating jsecurity_rating mgmt_rating  \
# 0           None          None           None             None        None
# 1           None          None           None             None        None
# 2           None          None           None             None        None
# 3           None          None           None             None        None
#
#   culture_rating reviews_count
# 0           None          None
# 1           None          None
# 2           None          None
# 3           None          None  >

# %%
# data cleaning
# add indeed prefix to job link and company link
prefix = 'http://www.indeed.com'


# iterate tthrough list in company_link
for list in df['company_link']:
    for line in list:
        # strip whitespace and page breaks
        company_link_clean = prefix + line 
        # add new column to data frame for cleaned name
        df['company_link_clean'] = company_link_clean
        print(company_link_clean)


for job in df['job_link']:
    for detail in job:
        # strip whitespace and page breaks
        job_link_clean = prefix + detail 
        # add new column to data frame for cleaned name
        df['job_link_clean'] = job_link_clean
        print(job_link_clean)
# Out:
# http://www.indeed.com/cmp/Usaa
# http://www.indeed.com/cmp/Usaa
# http://www.indeed.com/cmp/Wells-Fargo
# http://www.indeed.com/cmp/Usaa
# http://www.indeed.com/cmp/Circle-K
# http://www.indeed.com/cmp/Circle-K
# http://www.indeed.com/cmp/Transperfect-983d8371
# http://www.indeed.com/cmp/Discover-Financial-Services
# http://www.indeed.com/cmp/Nationwide-Mutual-Insurance-Company
# http://www.indeed.com/cmp/American-Express
# http://www.indeed.com/cmp/Lighthouse
# http://www.indeed.com/cmp/Shamrock-Foods-Company
# http://www.indeed.com/cmp/Deloitte
# http://www.indeed.com/cmp/Usaa
# http://www.indeed.com/cmp/Deloitte
# http://www.indeed.com/cmp/Usaa
# http://www.indeed.com/cmp/Lifesprk
# http://www.indeed.com/cmp/Health-Services-Advisory-Group,-Inc.
# http://www.indeed.com/cmp/Wipro
# http://www.indeed.com/cmp/American-Express
# http://www.indeed.com/cmp/Freeport--mcmoran
# http://www.indeed.com/cmp/Usaa
# http://www.indeed.com/cmp/Discount-Tire
# http://www.indeed.com/cmp/Nationwide-Mutual-Insurance-Company
# http://www.indeed.com/cmp/Freestar
# http://www.indeed.com/cmp/Usaa
# http://www.indeed.com/cmp/Usaa
# http://www.indeed.com/cmp/Lifesprk
# http://www.indeed.com/cmp/Albertsons
# http://www.indeed.com/cmp/Usaa
# http://www.indeed.com/cmp/Mckesson
# http://www.indeed.com/cmp/Usaa
# http://www.indeed.com/cmp/Bnp-Paribas
# http://www.indeed.com/cmp/American-Express
# http://www.indeed.com/cmp/Deloitte
# http://www.indeed.com/cmp/Usaa
# http://www.indeed.com/cmp/Usaa
# http://www.indeed.com/cmp/Lifesprk
# http://www.indeed.com/cmp/Tivity-Health
# http://www.indeed.com/cmp/Wells-Fargo
# http://www.indeed.com/cmp/Insight-596591c7
# http://www.indeed.com/cmp/Deloitte
# http://www.indeed.com/cmp/Deloitte
# http://www.indeed.com/cmp/Brightside
# http://www.indeed.com/cmp/Viasat
# http://www.indeed.com/cmp/Statistics-&-Data-Corporation-(sdc)
# http://www.indeed.com/cmp/Mufg
# http://www.indeed.com/cmp/Cable-One-5
# http://www.indeed.com/cmp/Deloitte
# http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0CdTBpsLrhs4IwmIsoO0brdHaF9POTtXIeJjdlamKYQ_HWXH6wnIvGcE5s_Z-CrGqndOyzCz_xoQC_reeUBFY_W6tVKOF8WUysGmMMxNVo_I1SPtT50b5FE7MSOYmAyd3JGkh8WKP2rkij3zd0g28AwNSm8TXkq2IJdkHKideL1UrQ3Gmclm9YzdW942jkXzDWJorpeu0Ts2Wri-tQbVJDLFrLcmlSzFlqntA1I6WXQLaDHEdnxHpByrm8he8KszEM83uFGcP0m9MgxRswu1OikMoRVowWEylxVlT1cLJttCiFE7TJ5zzGFYBe3c8wcatVVNXkq9jxAbQT85Oa2M5CSJ77M-8qWnEioN4vkCbLx2q-AqxT66PhfaQ5uk9d0I-D00v4qbtRjkA==&p=0&fvj=0&vjs=3
# http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN
://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0DIXU_djF9v0NrX_xbLRwj6RWFeuMEgTY6VvwKgvleOVN2aNd4LWgpeKXIdsYXWhN4CphXrRhlSMWNredBS0xbFHxwWNx8rjO2EFoVs4tCeTqsPrODzPB4agHP704Ubspolb6xZkNR3QQm78wCjbNW5fJpyZ9afRD--wSEy675REuf2uViGxmMRr61zOLp48JZxWpeRKR0ias-iu6oSjSnzgGYE6ayGzMDuArcvv2WSelcgYV4w8EE8xQ1eHa_qM5ZOKL86TfZqwsRLz79h69nl2-2Chaj3Ilzhj-YMeQJipDhDx7c-UU4WIO31ZrwQJi2FKXU6oUlI0kPFgIsB4qx2cwODdn8Fmbj1zvw9gel08J8IX_DxdqncOf4michPm4PtlIplsEDFSnqGd4cq8lO-K9AqpQgOC-4I76wtNDrokcyBYB8gMYUFaO4xcvlmGiUY4wz460kgJdG4elLFOZmuH1edNICvYyNZ4LM0kM35lIVJ3GWsqMQANJnjO6ENyt2vxIJDtU2Cn5FWd5N_LKfrAfiIUr3ARcGhEokJuE7NLUkiHkB8cWUM&p=15&fvj=0&vjs=3

# %%
# DATA CLEANING
# remove whitspace/page breaks from company name and ratings
    
 
# iterate through company names
for list in df['company_name']:
    for line in list:
        # strip whitespace and page breaks from
        company_name_clean = line.lstrip('\n')
        # add new column to data frame for cleaned name
        df['company_name_clean'] = company_name_clean
        print(company_name_clean)
        

for rating in df['ratings']:
    for detail in rating:
        ratings_clean = detail.replace('\n', '')
        df['ratings_clean'] = ratings_clean
        print(ratings_clean)
# Out:
# USAA
# USAA
# Wells Fargo Bank
# USAA
# Circle K
# Circle K
# TransPerfect
# Discover Financial Services
# Nationwide Mutual Insurance Company
# American Express
# Lighthouse
# Shamrock Foods
# Deloitte
# USAA
# Deloitte
# USAA
# Lifesprk
# Health Services Advisory Group, Inc.
# Wipro Limited
# American Express
# Freeport McMoRan
# USAA
# Discount Tire Corporate Careers
# Nationwide Mutual Insurance Company
# Freestar
# USAA
# USAA
# Lifesprk
# Albertsons Companies
# USAA
# McKesson
# USAA
# BNP Paribas
# American Express
# Deloitte
# USAA
# USAA
# Lifesprk
# Tivity Health, Inc.
# Wells Fargo
# Insight Enterprises, Inc.
# Deloitte
# Deloitte
# Brightside
# ViaSat
# Statistics &
#  Corporation (SDC)
# MUFG
# Cable One Inc.
# Deloitte
# 3.9
#
# 3.9
#
# 3.7
#
# 3.9
#
# 3.3
#
# 3.3
#
# 3.0
#
# 3.9
#
# 3.9
#
# 4.1
#
# 3.7
#
# 3.2
#
# 4.0
#
# 3.9
#
# 4.0
#
# 3.9
#
# 3.5
#
# 3.0
#
# 3.8
#
# 4.1
#
# 4.1
#
# 3.9
#
# 4.0
#
# 3.9
#
# 4.3
#
# 3.9
#
# 3.9
#
# 3.5
#
# 3.7
#
# 3.9
#
# 3.6
#
# 3.9
#
# 3.9
#
# 4.1
#
# 4.0
#
# 3.9
#
# 3.9
#
# 3.5
#
# 3.0
#
# 3.7
#
# 3.6
#
# 4.0
#
# 4.0
#
# 3.4
#
# 3.8
#
# 3.6
#
# 3.5
#
# 3.8
#
# 4.0
